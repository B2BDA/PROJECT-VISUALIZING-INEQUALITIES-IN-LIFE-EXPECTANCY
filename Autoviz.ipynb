# %%
import modin.pandas as pd

# %%
df = pd.read_csv(r"Downloads/UNdata_Export_20201212_063913455.csv")
df
# Out:
#   Country or Area Subgroup       Year  \
# 0           India   Female  2000-2005
# 1           India   Female  1995-2000
# 2           India   Female  1990-1995
# 3           India   Female  1985-1990
# 4           India     Male  2000-2005
# 5           India     Male  1995-2000
# 6           India     Male  1990-1995
# 7           India     Male  1985-1990
#
#                                               Source   Unit  Value  \
# 0  UNPD_World Population Prospects_2006 (Internat...  Years     64
# 1  UNPD_World Population Prospects_2006 (Internat...  Years     63
# 2  UNPD_World Population Prospects_2006 (Internat...  Years     61
# 3  UNPD_World Population Prospects_2006 (Internat...  Years     59
# 4  UNPD_World Population Prospects_2006 (Internat...  Years     62
# 5  UNPD_World Population Prospects_2006 (Internat...  Years     61
# 6  UNPD_World Population Prospects_2006 (Internat...  Years     60
# 7  UNPD_World Population Prospects_2006 (Internat...  Years     58
#
# ...

# %%
#importing Autoviz class
from autoviz.AutoViz_Class import AutoViz_Class
#Instantiate the AutoViz class
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
df = AV.AutoViz(r"Downloads/UNdata_Export_20201212_063913455.csv")
# Out:
# Shape of your Data Set: (8, 7)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  4
#     7 Predictors classified...
#         This does not include the Target column(s)
#         4 variables removed since they were ID or low-information variables
# Time to run AutoViz (in seconds) = 4.114
#
#  ###################### VISUALIZATION Completed ########################
